# %%
import pandas as pd
import os  
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
matplotlib.style.use('ggplot')
import pickle, gzip, urllib, json
import csv

# %%
# 万寿路
# 获取当前路径
cwd = os.getcwd()
print(cwd)
# Out:
# /Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/wanshoulu/csv

# %%
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/wanshoulu/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'wanshoulu.csv'

# %%
# 修改当前工作目录
os.chdir(Folder_Path)

# 将该文件夹下的所有文件名存入列表
file_list = os.listdir()
print(file_list)
type(file_list[0])
# Out:
# ['北京二手房数据 (21).csv', '北京二手房数据 (7).csv', '北京二手房数据 (17).csv', '北京二手房数据 (16).csv', '北京二手房数据 (6).csv', '北京二手房数据 (20).csv', '北京二手房数据.csv', '北京二手房数据 (1).csv', '北京二手房数据 (11).csv', '北京二手房数据 (10).csv', '北京二手房数据 (13).csv', '北京二手房数据 (3).csv', '北京二手房数据 (2).csv', '北京二手房数据 (12).csv', '北京二手房数据 (19).csv', '北京二手房数据 (9).csv', '北京二手房数据 (15).csv', '北京二手房数据 (5).csv', '北京二手房数据 (4).csv', '北京二手房数据 (14).csv', '北京二手房数据 (8).csv', '北京二手房数据 (18).csv', '北京二手房数据 (22).csv']
# str

# %%
#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

# %%
df.head()
# Out:
#                   房源      面积      均价     总价        成交日期        年代    户型   朝向  \
# 0  朱各庄小区 1室1厅 38.4平米  38.4平米  116407  447.0  2019-02-15  1984年建板楼  1室1厅    南
# 1  朱各庄小区 2室1厅 52.8平米  52.8平米   98107  518.0  2018-05-25  1984年建板楼  2室1厅    南
# 2  朱各庄小区 3室1厅 70.5平米  70.5平米   95745  675.0  2018-03-11  1984年建板楼  3室1厅  南 北
# 3  朱各庄小区 1室1厅 38.4平米  38.4平米  125000  480.0  2018-01-30  1984年建板楼  1室1厅    南
# 4  朱各庄小区 2室1厅 56.1平米  56.1平米  126560  710.0  2017-04-11  1984年建板楼  2室1厅  南 北
#
#          楼层  装修
# 0  中楼层(共6层)  精装
# 1  高楼层(共6层)  简装
# 2   底层(共6层)  精装
# 3   底层(共6层)  简装
# 4  低楼层(共6层)  精装

# %%
#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path +'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)

# %%
#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
df = pd.read_csv("/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities/wanshoulu.csv")

# %%
df.shape
# Out:
# (958, 10)

# %%
df.head()
# Out:
#                   房源      面积      均价     总价        成交日期        年代    户型   朝向  \
# 0  朱各庄小区 1室1厅 38.4平米  38.4平米  116407  447.0  2019-02-15  1984年建板楼  1室1厅    南
# 1  朱各庄小区 2室1厅 52.8平米  52.8平米   98107  518.0  2018-05-25  1984年建板楼  2室1厅    南
# 2  朱各庄小区 3室1厅 70.5平米  70.5平米   95745  675.0  2018-03-11  1984年建板楼  3室1厅  南 北
# 3  朱各庄小区 1室1厅 38.4平米  38.4平米  125000  480.0  2018-01-30  1984年建板楼  1室1厅    南
# 4  朱各庄小区 2室1厅 56.1平米  56.1平米  126560  710.0  2017-04-11  1984年建板楼  2室1厅  南 北
#
#          楼层  装修
# 0  中楼层(共6层)  精装
# 1  高楼层(共6层)  简装
# 2   底层(共6层)  精装
# 3   底层(共6层)  简装
# 4  低楼层(共6层)  精装

# %%
# 万柳
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/wanliu/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'wanliu.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 上地
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/shangdi/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'shangdi.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 世纪城
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/shijicheng/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'shijicheng.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 中关村
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/zhongguancun/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'zhongguancun.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 二里庄
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/erlizhuang/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'erlizhuang.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 五棵松
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/wukesong/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'wukesong.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 五道口
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/wudaokou/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'wudaokou.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 公主坟
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/gongzhufen/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'gongzhufen.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 六里桥
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/liuliqiao/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'liuliqiao.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 军博
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/junbo/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'junbo.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 北太平庄
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/beitaipingzhuang/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'beitaipingzhuang.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 厂洼
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/changwa/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'changwa.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 双榆树
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/shuangyushu/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'shuangyushu.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 四季青
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/sijiqing/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'sijiqing.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 圆明园
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/yuanmingyuan/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'yuanmingyuan.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 学院路
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/xueyuanlu/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'xueyuanlu.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 安宁庄
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/anningzhuang/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'anningzhuang.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 定慧寺
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/dinghuisi/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'dinghuisi.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 小西天
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/xiaoxitian/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'xiaoxitian.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 新街口
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/xinjiekou/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'xinjiekou.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 杨庄
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/yangzhuang/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'yangzhuang.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 海淀其他
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/haidianqita/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'haidianqita.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 海淀北部新区
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/haidianbeibuxinqu/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'haidianbeibuxinqu.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 清河
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/qinghe/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'qinghe.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 牡丹园
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/mudanyuan/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'mudanyuan.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 玉泉路
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/yuquanlu/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'yuquanlu.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 甘家口
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/ganjiakou/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'ganjiakou.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 田村
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/tiancun/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'tiancun.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 白石桥
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/baishiqiao/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'baishiqiao.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 皂君庙
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/zaojunmiao/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'zaojunmiao.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 知春路
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/zhichunlu/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'zhichunlu.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 紫竹桥
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/zizhuqiao/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'zizhuqiao.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 苏州桥
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/suzhouqiao/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'suzhouqiao.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 西三旗
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/xisanqi/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'xisanqi.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 西二旗
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/xierqi/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'xierqi.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 西北旺
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/xibeiwang/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'xibeiwang.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 西山
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/xishan/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'xishan.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 西直门
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/xizhimen/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'xizhimen.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 颐和园
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/yiheyuan/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'yiheyuan.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 马甸
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/madian/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'madian.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 马连洼
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/malianwa/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'malianwa.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 魏公村
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian/weigongcun/csv' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'weigongcun.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 海淀汇总
# 要拼接的文件夹及其完整路径，注不要包含中文
## 待读取批量csv的文件夹 
Folder_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities' 
## 待保存的合并后的csv的文件夹           
SaveFile_Path =  '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'  
## 待保存的合并后的csv       
SaveFile_Name = 'haidian.csv'  

#修改当前工作目录  
os.chdir(Folder_Path) 
#将该文件夹下的所有文件名存入一个列表  
file_list = os.listdir()  

#读取第一个CSV文件并包含表头  
df = pd.read_csv(Folder_Path +'//'+ file_list[0])  #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存  
df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False)  

#循环遍历列表中各个CSV文件名，并追加到合并后的文件  
FileStart = 1
FileEnd = len(file_list)
for i in range(FileStart,FileEnd):  
    df = pd.read_csv(Folder_Path + '//'+ file_list[i])  
    df.to_csv(SaveFile_Path+'//'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
df = pd.read_csv("/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian.csv")

# %%
df.shape
# Out:
# (72435, 10)

# %%
df.head()
# Out:
#                         房源       面积      均价      总价        成交日期          年代  \
# 0    中关村南大街甲3号 2室1厅 56.3平米   56.3平米   38544   217.0  2015-05-08    1965年建板楼
# 1    中关村南大街甲3号 2室1厅 55.1平米   55.1平米   33667   185.5  2012-04-10    1965年建板楼
# 2     民族大学南路19号院 2室1厅 70平米     70平米   91429   640.0  2019-04-19  1993年建板塔结合
# 3  民族大学南路19号院 2室1厅 98.49平米  98.49平米  102752  1012.0  2019-04-07    2000年建塔楼
# 4   民族大学南路19号院 2室1厅 60.7平米   60.7平米   98847   600.0  2019-02-22  1991年建板塔结合
#
#      户型   朝向         楼层  装修
# 0  2室1厅  南 北   低楼层(共3层)  简装
# 1  2室1厅  南 北    底层(共3层)  其他
# 2  2室1厅    南  中楼层(共15层)  简装
# 3  2室1厅    南  高楼层(共18层)  简装
# 4  2室1厅    南  高楼层(共16层)  其他

# %%
df.columns
# Out:
# Index(['房源', '面积', '均价', '总价', '成交日期', '年代', '户型', '朝向', '楼层', '装修'], dtype='object')

# %%
raw_data = pd.read_csv(
    "/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/haidian.csv",
    names=[
        "Housing ID", "Livable Area", "Price/Square Meter", "Price", "Transaction Date", "Year Built",
        "Floor Plan", "Facing Direction", "Floor", "Decoration"],
        sep=r'\s*,\s*',
        engine='python',
        na_values="?")

# %%
raw_data.head()
# Out:
#                 Housing ID Livable Area  Price/Square Meter   Price  \
# 0                       房源         None                 NaN     NaN
# 1    中关村南大街甲3号 2室1厅 56.3平米       56.3平米             38544.0   217.0
# 2    中关村南大街甲3号 2室1厅 55.1平米       55.1平米             33667.0   185.5
# 3     民族大学南路19号院 2室1厅 70平米         70平米             91429.0   640.0
# 4  民族大学南路19号院 2室1厅 98.49平米      98.49平米            102752.0  1012.0
#
#   Transaction Date  Year Built Floor Plan Facing Direction      Floor  \
# 0             None        None       None             None       None
# 1       2015-05-08    1965年建板楼       2室1厅              南 北   低楼层(共3层)
# 2       2012-04-10    1965年建板楼       2室1厅              南 北    底层(共3层)
# 3       2019-04-19  1993年建板塔结合       2室1厅                南  中楼层(共15层)
# 4       2019-04-07    2000年建塔楼       2室1厅                南  高楼层(共18层)
#
#   Decoration
# 0       None
# 1         简装
# 2         其他
# 3         简装
# 4         简装

# %%
raw_data = raw_data.drop([0])

# %%
raw_data.shape
# Out:
# (72435, 10)

# %%
raw_data.columns
# Out:
# Index(['Housing ID', 'Livable Area', 'Price/Square Meter', 'Price',
#        'Transaction Date', 'Year Built', 'Floor Plan', 'Facing Direction',
#        'Floor', 'Decoration'],
#       dtype='object')

# %%
raw_data.head()
# Out:
#                 Housing ID Livable Area  Price/Square Meter   Price  \
# 1    中关村南大街甲3号 2室1厅 56.3平米       56.3平米             38544.0   217.0
# 2    中关村南大街甲3号 2室1厅 55.1平米       55.1平米             33667.0   185.5
# 3     民族大学南路19号院 2室1厅 70平米         70平米             91429.0   640.0
# 4  民族大学南路19号院 2室1厅 98.49平米      98.49平米            102752.0  1012.0
# 5   民族大学南路19号院 2室1厅 60.7平米       60.7平米             98847.0   600.0
#
#   Transaction Date  Year Built Floor Plan Facing Direction      Floor  \
# 1       2015-05-08    1965年建板楼       2室1厅              南 北   低楼层(共3层)
# 2       2012-04-10    1965年建板楼       2室1厅              南 北    底层(共3层)
# 3       2019-04-19  1993年建板塔结合       2室1厅                南  中楼层(共15层)
# 4       2019-04-07    2000年建塔楼       2室1厅                南  高楼层(共18层)
# 5       2019-02-22  1991年建板塔结合       2室1厅                南  高楼层(共16层)
#
#   Decoration
# 1         简装
# 2         其他
# 3         简装
# 4         简装
# 5         其他

# %%
raw_data.dtypes
# Out:
# Housing ID             object
# Livable Area           object
# Price/Square Meter    float64
# Price                 float64
# Transaction Date       object
# Year Built             object
# Floor Plan             object
# Facing Direction       object
# Floor                  object
# Decoration             object
# dtype: object

# %%
os.getcwd()
# Out:
# '/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/cities'

# %%
raw_data.to_csv('/Users/Reinhard/Documents/Duke_Data Science/Fall 2020/702/Final Project/raw_haidian.csv')
